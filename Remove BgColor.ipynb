# %%
! pip install rembg

# %%
# Remove background from image
from rembg import remove
from PIL import Image
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
input_path = r'C:\Users\LENOVO\OneDrive\Desktop\Naresh IT\Tasks\Remove Background From Image\puppy.jpg'

# %%
output_path = r'C:\Users\LENOVO\OneDrive\Desktop\Naresh IT\Tasks\Remove Background From Image\puppy_img.png'

# %%
inp = Image.open(input_path)
inp
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1000>

# %%
output = remove(inp)

# %%
output.save(output_path)

# %%
Image.open(r'C:\Users\LENOVO\OneDrive\Desktop\Naresh IT\Tasks\Remove Background From Image\puppy_img.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x1000>
